# %%
# --------------------------------------------------------- MENU ---------------------------------------------------------

limite = 0
v = 0


while True:
    opcao = int(input("Insira uma opção:    1 - 26 ton      2- 40 ton      3- Misto"))
    v = float(input("Insira a velocidade do camião: "))
    num_motoristas = int(input("Insira o número de motoristas: "))
    

    if opcao == 1:
        limite = 12              # 26 ton nominais = 12 ton efetivas

        # Custos fixos
        #custos_fixos = (30 + 350 + 1800 + 950 + (4500 * num_motoristas)) / 313                # 365 - 52 = 313 (52 são o número de domingos no ano)
        custos_fixos = (30 + 350 + 1800 + 950 )*6 / 313

        # Custos variáveis
        combustivel = 0.6
        pneus = 0.03
        manutencao = 0.04

        break 
    
    elif opcao == 2:
        limite = 24              # 40 ton nominais = 24 ton efetivas

        # Custos fixos
        #custos_fixos = (45 + 480 + 2600 + 1900 + (4500 * num_motoristas)) / 313                # 365 - 52 = 313 (52 são o número de domingos no ano)
        custos_fixos = (45 + 480 + 2600 + 1900 )*6 / 313

        # Custos variáveis
        combustivel = 0.8
        pneus = 0.05
        manutencao = 0.06
        break  

    elif opcao == 3:
        limite = 16              # 16 ton efetivas    CENÁRIO MISTO

        # Custos fixos
        #custos_fixos = (30 + 350 + 1800 + 950 + (4500 * num_motoristas)) / 313                # 365 - 52 = 313 (52 são o número de domingos no ano)
        custos_fixos = (30 + 350 + 1800 + 950 )*6 / 313

        # Custos variáveis
        combustivel = 0.6
        pneus = 0.03
        manutencao = 0.04

        break  

print("-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* ROTAS OBTIDAS *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-")
# ------------------------------------------------------------------------------------------------------------------------



distancia_entre_clientes = {"Mangualde": {"Mangualde": 0.0, "Mirandela": 162.0, "Castelo Branco": 155.0, "Porto": 148.0,"Guarda": 60.2,"Lisboa": 298.0,"Coimbra": 95.6,"Vila Real": 113.0,"Viana do Castelo": 219.0,"Viseu": 23.4,"Braga": 200.0, "Évora": 344.0,"Beja": 432.0,"Setúbal": 331.0, "Faro": 537.0, "Portalegre": 245.0}, 
                            "Mirandela": {"Mangualde": 171.0, "Mirandela": 0.0, "Castelo Branco": 227.0, "Porto": 153.0,"Guarda": 132.0,"Lisboa": 433.0,"Coimbra": 230.0,"Vila Real": 63.6,"Viana do Castelo": 220.0,"Viseu": 145.0,"Braga": 167.0, "Évora": 416.0,"Beja": 496.0,"Setúbal": 465.0, "Faro": 676.0, "Portalegre": 317.0},
                            "Castelo Branco": {"Mangualde": 158.0, "Mirandela": 225.0, "Castelo Branco": 0.0, "Porto": 264.0,"Guarda": 93.9,"Lisboa": 231.0,"Coimbra": 146.0,"Vila Real": 261.0,"Viana do Castelo": 335.0,"Viseu": 173.0,"Braga": 316.0, "Évora": 200.0,"Beja": 279.0,"Setúbal": 263.0, "Faro": 470.0, "Portalegre": 100.0},
                            "Porto": {"Mangualde": 145.0, "Mirandela": 149.0, "Castelo Branco": 266.0, "Porto": 0.0,"Guarda": 202.0,"Lisboa": 317.0,"Coimbra": 121.0,"Vila Real": 94.5,"Viana do Castelo": 73.9,"Viseu": 132.0,"Braga": 58.2, "Évora": 409.0,"Beja": 451.0,"Setúbal": 349.0, "Faro": 556.0, "Portalegre": 296.0},
                            "Guarda": {"Mangualde": 62.9, "Mirandela": 130.0, "Castelo Branco": 93.9, "Porto": 202.0,"Guarda": 0.0,"Lisboa": 314.0,"Coimbra": 164.0,"Vila Real": 166.0,"Viana do Castelo": 272.0,"Viseu": 77.7,"Braga": 253.0, "Évora": 283.0,"Beja": 363.0,"Setúbal": 347.0, "Faro": 557.0, "Portalegre": 184.0},
                            "Setúbal": {"Mangualde": 325.0, "Mirandela": 461.0, "Castelo Branco": 263.0, "Porto": 349.0,"Guarda": 347.0,"Lisboa": 48.2,"Coimbra": 240.0,"Vila Real": 430.0,"Viana do Castelo": 420.0,"Viseu": 326.0,"Braga": 400.0, "Évora": 98.6,"Beja": 141.0,"Setúbal": 0.0, "Faro": 246.0, "Portalegre": 190.0},
                            "Faro": {"Mangualde": 531.0, "Mirandela": 667.0, "Castelo Branco": 468.0, "Porto": 554.0,"Guarda": 552.0,"Lisboa": 281.0,"Coimbra": 445.0,"Vila Real": 635.0,"Viana do Castelo": 625.0,"Viseu": 532.0,"Braga": 606.0, "Évora": 230.0,"Beja": 150.0,"Setúbal": 246.0, "Faro": 0.0, "Portalegre": 383.0},
                            "Portalegre": {"Mangualde": 248.0, "Mirandela": 315.0, "Castelo Branco": 99.7, "Porto": 294.0,"Guarda": 184.0,"Lisboa": 226.0,"Coimbra": 176.0,"Vila Real": 351.0,"Viana do Castelo": 365.0,"Viseu": 263.0,"Braga": 346.0, "Évora": 101.0,"Beja": 180.0,"Setúbal": 191.0, "Faro": 384.0, "Portalegre": 0.0},
                            }

janelas_temporais = {"Mirandela": [8,19], "Castelo Branco": [8,19], "Porto": [8,12], "Guarda": [8,18],
                "Lisboa": [14,19], "Coimbra": [10,14], "Vila Real": [14,19], "Viana do Castelo": [8,19],
                "Viseu": [10,16], "Braga":[8,16], "Évora": [8,19], "Beja": [8,19], "Setúbal": [14,19],
                "Faro": [8,20], "Portalegre": [8,19]}

capacidades = {"Mirandela": 2, "Castelo Branco": 2, "Porto": 3, "Guarda": 1,
                "Lisboa": 7, "Coimbra": 3, "Vila Real": 2, "Viana do Castelo": 2,
                "Viseu": 3, "Braga": 6, "Évora": 4, "Beja": 2, "Setúbal": 7,
                "Faro": 5, "Portalegre": 2}


import copy

lista_clientes = []

hora_inicio = 4
hora_fim = 20
hora_atual = 4

# Criar lista dos clientes
for cliente in distancia_entre_clientes:
    if cliente != "Mangualde":
        lista_clientes.append(cliente)


dist_camiao = 0             # Ditância total percorrida por todos os camiões
cap_total = 0
dist_cluster = 0            # # Ditância total percorrida por cada camião individual
cluster = 1
carga = descarga = 40/60


# ------------------------------------------------------------------------------------------------------------------------



while cap_total < 51:
    trajeto = ["Mangualde"]               # Forçar "Mangualde" no inicio do cluster
    local_atual = "Mangualde"             # # Forçar a começar em "Mangualde" 
    cap_camiao = 0
    minimo = 1000
    hora_atual = 4
    hora_inicio = 4
    dist_cluster = 0
    


    while cap_camiao <= limite:
      dist_hora_clientes = []
      minimo = 1000  # Inicializa com um valor grande para garantir que seja substituído
      
      


      for cliente in lista_clientes:

              dist_hora_clientes.append((distancia_entre_clientes[local_atual][cliente])/v)


      for pos_valor in range(0, len(dist_hora_clientes)):
              if len(trajeto) == 1:
                  minimo = max(dist_hora_clientes)                                # a var "minimo" é o máximo só para este caso
                  index_mais_proximo = dist_hora_clientes.index(minimo)
                  index_cliente_mais_proximo = index_mais_proximo  # Ajuste conforme necessário
                  cliente_mais_proximo = lista_clientes[index_mais_proximo]

              else:
                   
                if dist_hora_clientes[pos_valor] + hora_atual >= janelas_temporais[lista_clientes[pos_valor]][0] and dist_hora_clientes[pos_valor] + hora_atual <= janelas_temporais[lista_clientes[pos_valor]][1] and lista_clientes[pos_valor] != local_atual:
                    if dist_hora_clientes[pos_valor] < minimo: 
                        minimo = dist_hora_clientes[pos_valor]
                        index_mais_proximo = dist_hora_clientes.index(minimo)
                        index_cliente_mais_proximo = index_mais_proximo  # Ajuste conforme necessário
                        cliente_mais_proximo = lista_clientes[index_mais_proximo]


      
      print(f"Hora chegada cliente: {hora_atual}")
      if cap_camiao + capacidades[cliente_mais_proximo] <= limite and cliente_mais_proximo not in trajeto:    
              trajeto.append(cliente_mais_proximo)
              dist_camiao = dist_camiao + distancia_entre_clientes[local_atual][cliente_mais_proximo]
              dist_cluster = dist_cluster + distancia_entre_clientes[local_atual][cliente_mais_proximo]
              cap_camiao = cap_camiao + capacidades[cliente_mais_proximo]
              cap_total = cap_total + capacidades[cliente_mais_proximo] 
              local_atual = cliente_mais_proximo 
              lista_clientes.remove(cliente_mais_proximo)

              if len(trajeto) == 2:  
                    if hora_inicio + minimo + carga <= janelas_temporais[cliente_mais_proximo][0]:
                        hora_inicio = janelas_temporais[cliente_mais_proximo][0] - minimo - carga
                        hora_atual = hora_inicio + minimo + descarga
                        if hora_inicio + minimo + carga <= 8 :
                             hora_inicio = 8 - minimo -carga
                             hora_atual = hora_inicio + minimo + descarga
                    else:
                        hora_inicio = hora_inicio    # Supor já carregado
                        hora_atual = hora_inicio + minimo + descarga
              else:
                   hora_atual = hora_atual + minimo + descarga

              



      else:
              break

    trajeto.append("Mangualde")
    dist_camiao = dist_camiao + distancia_entre_clientes[cliente_mais_proximo]["Mangualde"]                        # Adicionar distância de regresso a Mangualde
    dist_cluster = dist_cluster + distancia_entre_clientes[cliente_mais_proximo]["Mangualde"]                      # Adicionar distância de regresso a Mangualde

    custo_rota = custos_fixos + (combustivel * dist_cluster) + (pneus * dist_cluster) + (manutencao * dist_cluster)
    print(f'Cluster {cluster}: {trajeto}. Capacidade: {cap_camiao} ton. Distância percorrida: {dist_cluster:.2f} km. Custos Rota {cluster}: {custo_rota:.2f} €')
    print(f"Hora Início: {hora_inicio:.2f} h")
    print(f"Hora Chegada ao último cliente: {hora_atual:.2f} h")
    tempo_total = hora_atual + (distancia_entre_clientes[cliente_mais_proximo]["Mangualde"]/v)
    print(f"Hora Chegada a Mangualde: {tempo_total:.2f} h")

    cluster += 1

print("-*"*92)

print(f"Número de Camiões: {cluster-1}")
print(f"Número de Motoristas: {num_motoristas}")
print(f"Distância total: {dist_camiao:.2f} km")
print(f"Custo total diário: {(custos_fixos * (cluster-1) + (combustivel * dist_camiao) + (pneus * dist_camiao) + (manutencao * dist_camiao)):.2f} €")
print("Capacidade total atingida ... ")
# Out:
# -*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-* ROTAS OBTIDAS *-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-*-
# Hora chegada cliente: 4
# Hora chegada cliente: 10.984313725490194
# Hora chegada cliente: 13.4156862745098
# Hora chegada cliente: 15.023529411764702
# Cluster 1: ['Mangualde', 'Faro', 'Beja', 'Évora', 'Mangualde']. Capacidade: 11 ton. Distância percorrida: 1092.00 km. Custos Rota 1: 791.64 €
# Hora Início: 4.00 h
# Hora Chegada ao último cliente: 15.02 h
# Hora Chegada a Mangualde: 18.85 h
# Hora chegada cliente: 4
# Hora chegada cliente: 14.0
# Hora chegada cliente: 15.233725490196077
# Hora chegada cliente: 18.55921568627451
# Cluster 2: ['Mangualde', 'Setúbal', 'Lisboa', 'Portalegre', 'Mangualde']. Capacidade: 16 ton. Distância percorrida: 853.20 km. Custos Rota 2: 631.64 €
# Hora Início: 9.44 h
# Hora Chegada ao último cliente: 18.56 h
# Hora Chegada a Mangualde: 21.48 h
# ...
